# %% [markdown]
# Q. Explain the key features of Python that make it a popular choice for        programming.
#
# Ans. Python is a dynamic,hig-level, free open source and interpreted programming language. It is a set of rules and symbols that define the process of writing computer program.it is commonly used for developing website and software,task automation,data analysis and data visualisation.
# Features of Python are:-
# 1.Free and Open source.
# 2.Easy to read and code.
# 3.Object-Oriented Language.
# 4.Large no. of Standard Libraries.
# 5.Python is Interpreted langugae.
# 6.Supports large community.
# 7.It is a high-level language.
#
#
# Q. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
# Ans.  Predefined keywords in Python have special meanings and cannot be used as variable names. They control the language’s syntax and operations. Here are some examples:-

# %%
1. `if`,`elif`,`else` : Conditional statements.

2. `for`,`while`,`break`,`continue` : Loop control.

3. `def`,`return` : Function definition.

4. `class`,`self` : Class definition.

5. `try`,`except`,`finally`: Exception handling.

6. `import`,`from`,`as`: Module import.

7. `True`,`False`,`None`: Boolean and null values.

8. `with`,`as`: Context management.

# %% [markdown]
# # New Section

# %% [markdown]
# Q. Compare and contrast mutable and immutable objects in 	Python with examples.
#
# Ans. Mutable Objects:
# Mutable objects are those which can be changed after creation.
# Examples: Lists, dictionaries, sets.
#
#   Immutable Objects:
# Immutable objects are those which cannot be changed after creation.
# Examples: Strings, tuples, integers, float.
#
# # Key Differences:
# * Modification:
# Mutable: The objects can be modified after the creation.
# Immutable: Objects can not be modified after the creation.
#
# * Hashability:
# Mutable: Not hashable(cannot be used as keys in dictionaries or elements in sets).
# Immutable: Hashable(can be used as keys in dictionaries and elements in sets).
#
# * Memory efficiency:
# Mutable: It may consumes more memory as compared to immutable objects due to changes.
# Immutable: Typically memory efficient as new objects are not created for changes.
#
# Examples:
# Mutable: my_list-[1,2,3]<br>my_list.append(4).
# Immutable: my_string - "hello"<br>my_string.upper().

# %% [markdown]
# Q. Discuss the different types of operators in Python and provide examples of how they are used.

# %%
Ans. 1. Arithmetic Operators: Perform mathematical operations.
`+`: Addition
            result = 5 + 3  # Output: 8
`-`: Subtraction
            result = 5 - 3  # Output: 2
`*`: Multiplication
            result =5 * 3  # Output: 15
`/`: Division
            result = 5 / 2  # Output: 2.5

     2. Comparison Operators: Compare values and return a boolean.
`==`: Equal to
              result = ( 5 == 3)  # Output: False
`!=`: Not equal to
              result = (5 != 3)  # Output: True

    3. Logical Operators: Combine conditional statements.
`and`:
      result = (5 > 3 and 5 < 10)  # Output: True
`or`:
      result = (5 < 3 or 5 < 10)  # Output: True

`not`:
      result = not (5 > 3) # Output: False

    4. Assignment Operators: Assign values to variables.
`=`: Assign
             a = 2
`+=`: Add and assign
             a += 3  # Equivalent to a = a + 3

    5. Bitwise Operators: Perform operation on binary numbers.
`&`:
         result = 5 & 3  # Output: 1

    6. Identity Operators: Check if two variables refers to the same object.
`is`:
       a = 2
       b = 2
            a is b  # Output: True
`is not`:
      a = 2
      b = 2
            a is not b  # Output: False

    7. Membership Operators: Check for membership in sequences.
`in`:
       a = "Namita"
           "N" in a  # Output: True
`not in`:
       a = "Namita"
           "N" not in a  # Output: False

These are the main types of operators.

# %% [markdown]
# Q. Explain the concept of type casting in Python with examples.
#
# Ans. The process of converting a value from one data type to another data type is called Typecasting.This can be done explicitly using built-in functions.
#
# Examples:

# %%
1. String to Integer:
           str_num = "5"
           int_num = int(str_num)
           print(int_num)  # Output: 5

2. Float to Integer:
          num = 2.5
          int_num = int(num)
          print(int_num)  # Output: 2

3. Integer to Float:
          num = 2
          float_num = float(num)
          print(float_num)  # Output: 2.0

4. Integer to String:
          num = 23
          str_num = str(num)
          print(str_num)  # Output: "23"
# Out:
#   File "<ipython-input-2-80bd80d4e490>", line 1
#     1. String to Integer:
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q. How do conditional statements work in Python? Illustrate with examples.
#
# Ans. Conditional statements are those which describe the relationship between two events based on certain conditions.

# %%
Examples:
1.`if`:
       a = 50
       if a > 20:
          print ("The number is greater than 20")  # Output ("The number is greater than 20")

2.`if-else`:
       a = 3
       if a > 5:
          print("a is greater than 5")
       else:
          print("a is not greater than 5")  # Output ("a is not greater than 5")

3.`elif`:
       a = 5
       if a > 5:
         print("a is greater than 5")
       elif a == 5:
         print("a is equal to 5")
       else:
         print("a is less than 5")  # Output ("a is equal to 5")

# %% [markdown]
# Q. Describe the different types of loops in Python and their use cases with examples.
#
# Ans. Python has two main types of loops: `for` loops and `while` loops.It executes a block of code multiple times based on a condition.
# 1. For Loop: Used to iterate over a sequence of elements,(like string or set,list,tuple,dictionary).

# %%
Example:
        Fruits = ["apple", "banana", "cherry"]
        for Fruit in Fruits:
            print(Fruit)  # Output: ("apple,banana,cherry")

# %% [markdown]
# 2. While Loop: Repeats a block of code as long as a specified condition is true.

# %%
#Print numbers from 1 to 9

       count = 1
       while count <= 9:
          print(count)
          count += 1       # Output: ("1,2,3,4,5,6,7,8,9")

# %% [markdown]
# 3. Nested Loops: You can use one loop inside another loop.Useful for multi-dimensional data.

# %%
Example:
       for i in range(3):
          for j in range(2):
              print(f"i: {i}, {j}")  # Output: i:0, j:0, i:0, j:0........
